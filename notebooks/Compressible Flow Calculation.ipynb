# %% [markdown]
# <center><h1>可压缩流动相关计算</h1></center>
# <center><h4>韩国晨</h4></center>
# <center><h4>Jan-2026</h4></center>
#
#
# ## 前言
# 本文旨在学习理论和算法，而非实现某个工业应用，因此后续对算法进行了适当简化，以便练习。
#
# ## 数值方法
# 在数值分析的学习中，我们已经接触了二分法、牛顿法、割线法三种基本的求根算法。下面将介绍最后一种算法—不动点迭代。
#
# ### 不动点迭代
# 从函数图像看出，多项式 $x^2 − 5 = 0$ 的两个根大约是$\pm 2.5$，下面看看不动点迭代是如何求解的。

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 50)
y = x**2 - 5

plt.figure(figsize=(4, 3)) # 4" x 3"
plt.plot(x, y, label='f(x) = x² - 5')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y=0, color='k', linewidth=1)
plt.axvline(x=0, color='k', linewidth=1)
plt.grid(alpha=0.3, linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# 首先将原方程改写为 $x=g(x)$ 的形式。一种可行的变换如下:
# $$
# x=\frac{3x^2-5}{2x}
# $$
# 由此得到迭代公式：
# $$
# x_{n+1}=\frac{3x_n^2-5}{2x_n}
# $$
#
# 从 $x_0=0.5$ 开始迭代，结果如下。
# $$
# \begin{array}{c c l c}
# \hline
# n & x_{n+1} & g(x_n) & |\Delta x| \\
# \hline
# 0 & -4.25 & (3 \times 0.5^2 - 5) / (2 \times 0.5) = -4.25 & - \\
# 1 & -6.08824 & (3 \times (-4.25)^2 - 5) / (2 \times (-4.25)) \approx -6.08824 & 1.83824 \\
# 2 & -9.04348 & (3 \times (-6.08824)^2 - 5) / (2 \times (-6.08824)) \approx -9.04348 & 2.95524 \\
# 3 & -13.56522 & (3 \times (-9.04348)^2 - 5) / (2 \times (-9.04348)) \approx -13.56522 & 4.52174 \\
# 4 & -20.34783 & (3 \times (-13.56522)^2 - 5) / (2 \times (-13.56522)) \approx -20.34783 & 6.78261 \\
# 5 & -30.52174 & (3 \times (-20.34783)^2 - 5) / (2 \times (-20.34783)) \approx -30.52174 & 10.17391 \\
# 6 & -45.78261 & (3 \times (-30.52174)^2 - 5) / (2 \times (-30.52174)) \approx -45.78261 & 15.26087 \\
# 7 & -68.67391 & (3 \times (-45.78261)^2 - 5) / (2 \times (-45.78261)) \approx -68.67391 & 22.89130 \\
# 8 & -103.02174 & (3 \times (-68.67391)^2 - 5) / (2 \times (-68.67391)) \approx -103.02174 & 34.34783 \\
# 9 & -154.52174 & (3 \times (-103.02174)^2 - 5) / (2 \times (-103.02174)) \approx -154.52174 & 51.50000 \\
# 10 & -231.78261 & (3 \times (-154.52174)^2 - 5) / (2 \times (-154.52174)) \approx -231.78261 & 77.26087 \\
# \hline
# \end{array}
# $$
# 显然，迭代不收敛。
#
# 下面换另一种等价的转换：
# $$
# x_{n+1}=\frac{x_n+5}{x_n+1}
# $$
# 仍然从 $x_0=0.5$ 开始，结果如下。
# $$
# \begin{array}{c c c c}
# \hline
# n & x_{n+1} & g(x_n) & |\Delta x| \\
# \hline
# 0 & 3.66667 & (0.5 + 5) / (0.5 + 1) \approx 3.66667 & - \\
# 1 & 1.85714 & (3.66667 + 5) / (3.66667 + 1) \approx 1.85714 & 1.80952 \\
# 2 & 2.40000 & (1.85714 + 5) / (1.85714 + 1) \approx 2.40000 & 0.54286 \\
# 3 & 2.17647 & (2.40000 + 5) / (2.40000 + 1) \approx 2.17647 & 0.22353 \\
# 4 & 2.25926 & (2.17647 + 5) / (2.17647 + 1) \approx 2.25926 & 0.08279 \\
# 5 & 2.22727 & (2.25926 + 5) / (2.25926 + 1) \approx 2.22727 & 0.03199 \\
# 6 & 2.23944 & (2.22727 + 5) / (2.22727 + 1) \approx 2.23944 & 0.01216 \\
# 7 & 2.23478 & (2.23944 + 5) / (2.23944 + 1) \approx 2.23478 & 0.00465 \\
# 8 & 2.23656 & (2.23478 + 5) / (2.23478 + 1) \approx 2.23656 & 0.00178 \\
# 9 & 2.23588 & (2.23656 + 5) / (2.23656 + 1) \approx 2.23588 & 0.00068 \\
# 10 & 2.23614 & (2.23588 + 5) / (2.23588 + 1) \approx 2.23614 & 0.00026 \\
# \hline
# \end{array}
# $$
#
# 这一次收敛了。那么，什么情况下才会收敛呢？
#
# 从几何角度理解不动点迭代，求根的本质就是求直线 $y=x$ 和 曲线 $y=g(x)$ 交点的 x 坐标，记作 $x^*$。交点即所谓的“不动点”。
# <div align="center">
#   <img src="https://pages.hmc.edu/ruye/MachineLearning/lectures/figures/fixedpoint.png" width="30%">
# </div>
#
# 接着在不动点对 $g(x)$ 进行泰勒展开：
# $$
# g(x)=g(x^*)+\frac{(x-x^*)^1}{1!} g'(x^*)+ \frac{(x-x^*)^2}{2!} g''(x^*)+ \frac{(x-x^*)^3}{3!} g'''(x^*)+\cdots
# $$
#
# 取其线性部分：
# $$
# g(x)\approx g(x^*)+(x-x^*)g'(x^*) \Longrightarrow g(x)-g(x^*) \approx (x-x^*)g'(x^*)
# $$
# 利用不动点坐标相等的条件，即 $x^*=g(x^*)$，将其代入上式：
# $$
# g(x)-x^* \approx (x-x^*)g'(x^*)
# $$
#
# 令 $x=x_n$，有：
# $$
# g(x_n)-x^* \approx (x_n-x^*)g'(x^*)
# $$
# 根据迭代公式，有 $x_{n+1}=g(x_n)$，则：
# $$
# x_{n+1}-x^* \approx (x_n-x^*)g'(x^*)
# $$
# 这说明：当前轮到精确解的距离等于上一轮距离乘以不动点的导数。如果导数的绝对值 $|g'(x^*)|$ 小于 1，则会不断逼近精确解，迭代收敛，反之发散。
#
# 计算上述两个转换不动点导数的绝对值，发现收敛转换对应的值小于1。
# $$
# \begin{gather*}
#     |g_1'(\sqrt{5})| = \left|\frac{3(\sqrt{5})^2 + 5}{2(\sqrt{5})^2}\right| = |2|=2\\[2ex]
#     |g_2'(\sqrt{5})| = \left|\frac{-2(3 - \sqrt{5})}{4}\right| = |-0.382|=0.382
# \end{gather*}
# $$
#
# ### 方程组求解
# 很多工程问题最后都会落到求解非线性方程组，解法一般采用牛顿迭代。不动点迭代也可求解，过程如下。
# $$
# \left\{
# \begin{aligned}
# p_{n+1}=f(p_n) \\[2ex]
# T_{n+1}=g(T_n)
# \end{aligned}
# \right.
# $$
# 当满足切比雪夫范数 $\mathrm{min}(|p_{n+1}-p_{n}|, |T_{n+1}-T_{n}|) <\epsilon $ 条件时，迭代收敛。
#
# ## 流动方程
# 管道和喷嘴是工程中最常见的流道，其中的可压缩流体流动比较复杂。可压缩流体在等截面管道内的常见流动包括绝热流动和等温流动两种型式。流体在较短裸管段内的流动可以视为绝热流动。这是因为流体在离开管道之前，只能与环境进行非常短暂的换热，所以换热量可忽略不计。安全阀的排放是一种典型的绝热流动。对于较长的裸管，由于流体能够充分与环境进行换热，并最终达到热平衡，因此一般视为等温流动。
#
# **本文探讨的是一维，稳态，可压缩流体的摩擦管流，且管道截面积不变**。一维指流动中流体的各物理量（速度、压力、温度等）仅沿管道轴向变化；稳态指任一点的流动参数不随时间变化。
#
# ### 控制方程
#
# 任何流动都受质量守恒方程的制约，考虑摩擦的流动还受如下形式动量守恒方程的制约。
# $$
# \begin{gather*}
#     \rho_1 V_1A_1 = \rho_2 V_2A_2 \tag{质量守恒方程}\\[2ex]
#     p_1 + \rho_1 V_1^2 = p_2 + \rho_2 V_2^2 + f_d \frac{L}{D_h} \cdot \frac{\rho_1 V_1^2}{2} \tag{动量守恒方程}
# \end{gather*}
# $$
#
# 绝热流动，工程上又称 **Fanno 流动**，还受能量守恒方程的制约。
# $$
# h_1 + \frac{V_1^2}{2} = h_2 + \frac{V_2^2}{2} + q \tag{能量守恒方程}
# $$
#
# 绝热流动要求 $p、T、V$ 三个未知量，因此需联立这三个守恒方程求解。等温流动的温度无需求解，仅要求得 $p、V$，因此联立质量守恒和动量守恒方程即可。此外，由于等温流动中存在显著的换热，能量守恒方程也不适用于它。
#
# ### 物性方程
#
# 在上述方程中，除了 $p, T, V$ 这三个未知量，还有 $\rho、h$ 要求，显然还得再找两个方程。
#
# 简单一点，通过理想气体方状态程将密度的关系转化为压力和温度的关系。
# $$
# \rho=\frac{p}{RT}\Longrightarrow\frac{\rho_2}{\rho_1}=\frac{p_2T_1}{T_2p_1}
# $$
#
# 此外，根据比焓降的热力学定义式，可将其转化为温度的关系（认为定压比热容在流动过程中不变）。
# $$
# \mathrm{d}h = c_p\mathrm{d}T
# $$
# 气体的定压比热容对温度不敏感。例如，空气的温度从 -18 C 升至 2760 C，定压比热容仅上升 30%。因此，假定定压比热容不变是可行的。
#
# ### 计算单元
# 将整个管道分成 N 个计算单元，逐段计算，每段的出口参数作为下一段的进口参数。如此往复，迭代推进。分段越短，误差越小，但计算量亦随之增加。
#
# 以绝热流动为例，下图示意了计算单元的结构。进口参数（$p_1,T_1,V_1$）和几何尺寸（$L,D_h$）已知，求出口参数（$p_2,T_2,V_2$）。
# <diV align="center">
#   <img src="https://i0.wp.com/tvax2.sinaimg.cn/large/009dZlbQgy1i9dy3ryvglj30in05mt91.jpg">
# </div>
# ## 绝热管流
# 本节首先用物性方程化简控制方程，再用 Python 实现。
# ### 方程化简
# 将质量方程代入能量方程，消去速度项与密度项，统一变量为压力和温度。能量方程化简为：
# $$
#     h_2 - h_1 = \frac{{V_1}^2-{V_2}^2}{2} \Longrightarrow
#     c_p(T_2-T_1)=\frac{1}{2}\left[V_1^2-V_1^2{\left(\frac{\rho_1}{\rho_2}\right)}^2\right] \Longrightarrow
#     \boxed{2c_p(\color{magenta}{T_2}-T_1)=V_1^2\left[1-{\left(\frac{\color{magenta}{T_2}p_1}
#     {\color{magenta}{p_2}T_1}\right)}^2\right]}
# $$
#
# 动量方程化简为：
# $$
# \begin{align*}
# &p_1 + \rho_1 V_1^2 = p_2 + \rho_2 V_2^2 + f_d \frac{\mathrm{d}L}{D_h} \cdot \frac{\rho_1 V_1^2}{2}\Longrightarrow
# p_1 + \frac{p_1}{RT_1} V_1^2=p_2 + \frac{p_2}{RT_2} V_2^2+ f_d \frac{\mathrm{d}L}{D_h} \cdot \frac{p_1 V_1^2}{2RT_1}\Longrightarrow\\[2ex]
# &p_1 + \frac{p_1}{RT_1} V_1^2=p_2+ \frac{p_2}{RT_2} V_1^2\left(\frac{p_1 T_2}{p_2 T_1}\right)^2+ f_d \frac{\mathrm{d}L}{D_h} \cdot \frac{p_1 V_1^2}{2RT_1}
# \Longrightarrow
# \boxed{p_1 + \frac{p_1}{RT_1} V_1^2=\color{magenta}{p_2}+ V_1^2 \cdot \frac{p_1^2 \color{magenta}{T_2}}{RT_1^2\color{magenta}{p_2} }+ f_d \frac{\mathrm{d}L}{D_h} \cdot \frac{p_1 V_1^2}{2RT_1}}
# \end{align*}
# $$
# ### 编程实现
# 以下示例程序包含两个核心函数。fanno_segment 的功能是以管段进口参数为输入，利用控制方程，通过不动点迭代求解出口参数。fanno_pipe 再通过一个“死循环”反复调用 fanno_segment 。每次调用前，更新当前管段的进口参数为上一管段的出口参数。由此，程序得以沿管长逐段推进，直至异常抛出。
#
# 达到最大迭代次数后，fanno_segment 会立刻抛出异常；fanno_pipe 捕获到此异常后，就跳出“死循环”，终止计算。程序最终返回到主函数 main，输出结果后退出。

# %%
from tabulate import tabulate

# ========================================================================================
# Fanno Flow - Multi-Segment Solver (SI Units)
# Author: Robin Han
# Date: December, 2025
# All variables are in SI:
# Pressure (Pa), Temperature (K), Velocity (m/s), Length (m), Diameter (m), R (J/kg·K)
# ========================================================================================

# Nitrogen properties
R = 8.314 / 28.014e-3  # J/kg·K (gas constant for N2)
CP = 1072.0  # J/kg·K (specififc heat at constant pressure@20bara/20C)
K = 1.4  # ratio of specific heats for diatomic gas (approx)

# Numerical parameters
TOL = 1e-6  # convergence tolerance for p2 and T2
MAX_ITER = 200  # maximum iterations per segment


def isothermal_segment(p1, T1, V1, fd, D, dL):
    """
    Solve one Fanno-flow segment using fixed-point iteration.

    Inputs:
        p1 : inlet pressure  (Pa)
        T1 : inlet temperature (K)
        V1 : inlet velocity (m/s)

    Returns:
        p2 : outlet pressure (Pa)
        T2 : outlet temperature (K)
        V2 : outlet velocity (m/s)
    """

    # Initial guesses for unknown outlet values
    p2 = 0.95 * p1
    T2 = T1

    counter = 0
    while counter < MAX_ITER:

        # --- Update pressure from momentum equation ---
        # p1 + (p1/(RG*T1))*V1^2 = p2 + V1^2 * (p1^2 * T2)/(RG*T1^2 * p2) + F*L/D *K*(p1*V1^2)/(2*RG*T1)
        # -> p2 = p1 + (p1*V1^2)/(RG*T1) - V1^2 * p1^2 * T2 / (RG*T1^2*p2) - F*L/D * p1 * V1^2 / (2*RG*T1)
        p2_new = p1 + (p1 * V1**2) / (R * T1) - (V1**2 * p1**2 * T2) / (R * T1**2 * p2) - (fd * dL / D * p1 * V1**2) / (2 * R * T1)

        # --- Update temperature from energy equation ---
        # 2*cp*(T2 - T1) = V1^2 * [1 - (T2*p1/(p2*T1))^2]
        # -> T2 = T1 + V1^2 * (1 - (T2*p1/(p2*T1))^2) / (2*Cp)
        T2_new = T1 + V1**2 * (1 - (T2 * p1 / (p2_new * T1)) ** 2) / (2 * CP)

        # Convergence check on both pressure and temperature
        if min(abs(p2_new - p2), abs(T2_new - T2)) < TOL:
            p2, T2 = p2_new, T2_new
            break

        # Go to next iteration using updated values
        p2, T2 = p2_new, T2_new
        counter += 1
    else:
        # Only executed if while loop exits without break
        raise RuntimeError("Lack of convergence in fanno_segment")

    # --- Compute outlet velocity using mass conservation ---
    # rho1 * V1 = rho2 * V2, rho = P / (RG*T)
    rho1 = p1 / (R * T1)
    rho2 = p2 / (R * T2)
    V2 = rho1 * V1 / rho2

    return p2, T2, V2


def isothermal_pipe(p0, T0, V0, fd, D, dL):
    """
    March along the pipe using multiple Fanno segments.
    Uses an infinite loop to advance segment by segment
    until:
      - lack of convergence (numerical issue), or
      - choking (Mach number close to 1)

    Returns:
        results : list of (P, T, V, M) at each segment outlet
    """

    total_length = 0.0
    results = []

    p1, T1, V1 = p0, T0, V0
    while True:
        try:
            p2, T2, V2 = isothermal_segment(p1, T1, V1, fd, D, dL)
        except RuntimeError as e:
            print(f"\n[Warning] {e}. Stopping at length = {total_length:.3f} m")
            break

        total_length += dL
        c2 = (K * R * T2) ** 0.5
        Ma2 = V2 / c2
        results.append((total_length, p2, T2, V2, Ma2))

        p1, T1, V1 = p2, T2, V2

    return results

if __name__ == "__main__":
    # 20 bara, 20 C, 100 m/s, fd = 0.02, D = 0.1, dL = 0.01
    profile = isothermal_pipe(20e5, 20.0 + 273.15, 100.0, 0.02, 0.1, 0.1)

    headers = ["No.", "Length (m)", "Pressure (bara)", "Temp (C)", "Velocity (m/s)", "Mach Number"]
    table_data = []
    for i, (L, p, t, v, ma) in enumerate(profile):
        table_data.append([i, f"{L:.3f}", f"{p/1E5:.3f}", f"{t-273.15:.1f}", f"{v:.3f}", f"{ma:.3f}"])

    print(tabulate(table_data, headers=headers, tablefmt="grid", stralign="center", numalign="center"))
# Out:
# [Warning] Lack of convergence in fanno_segment. Stopping at length = 29.800 m
# +-------+--------------+-------------------+------------+------------------+---------------+
# |
|
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  267  |     26.8     |       9.837       |     7      |      194.34      |     0.57      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  268  |     26.9     |       9.761       |    6.8     |     195.669      |     0.574     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  269  |      27      |       9.685       |    6.6     |     197.036      |     0.578     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  270  |     27.1     |       9.607       |    6.3     |     198.445      |     0.582     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  271  |     27.2     |       9.528       |     6      |     199.897      |     0.587     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  272  |     27.3     |       9.448       |    5.7     |     201.395      |     0.592     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  273  |     27.4     |       9.366       |    5.5     |     202.944      |     0.596     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  274  |     27.5     |       9.283       |    5.1     |     204.545      |     0.602     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  275  |     27.6     |       9.197       |    4.8     |     206.202      |     0.607     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  276  |     27.7     |       9.11        |    4.5     |     207.921      |     0.612     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  277  |     27.8     |       9.022       |    4.2     |     209.704      |     0.618     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  278  |     27.9     |       8.931       |    3.8     |     211.559      |     0.624     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  279  |      28      |       8.838       |    3.4     |     213.491      |     0.63      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  280  |     28.1     |       8.742       |     3      |     215.506      |     0.636     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  281  |     28.2     |       8.644       |    2.6     |     217.612      |     0.643     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  282  |     28.3     |       8.544       |    2.1     |     219.819      |     0.65      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  283  |     28.4     |       8.44        |    1.6     |     222.136      |     0.657     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  284  |     28.5     |       8.333       |    1.1     |     224.577      |     0.665     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  285  |     28.6     |       8.222       |    0.6     |     227.155      |     0.674     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  286  |     28.7     |       8.107       |     0      |     229.889      |     0.682     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  287  |     28.8     |       7.987       |    -0.6    |     232.799      |     0.692     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  288  |     28.9     |       7.862       |    -1.3    |     235.913      |     0.702     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  289  |      29      |       7.731       |     -2     |     239.262      |     0.713     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  290  |     29.1     |       7.592       |    -2.9    |     242.891      |     0.725     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  291  |     29.2     |       7.445       |    -3.8    |     246.857      |     0.738     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  292  |     29.3     |       7.288       |    -4.8    |     251.237      |     0.752     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  293  |     29.4     |       7.117       |    -5.9    |     256.146      |     0.769     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  294  |     29.5     |       6.929       |    -7.3    |     261.754      |     0.788     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  295  |     29.6     |       6.718       |    -8.9    |     268.353      |     0.81      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  296  |     29.7     |       6.469       |    -11     |     276.493      |     0.838     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  297  |     29.8     |       6.151       |   -13.9    |     287.548      |     0.876     |
# +-------+--------------+-------------------+------------+------------------+---------------+

# %% [markdown]
# ### 剩余长度
# 在 Fanno 流动中，无论起始马赫数是亚音速还是超音速，随着流动沿程推进，马赫数都会向 1 逼近，最终达到称为“阻塞”（choking）的状态。从当前马赫数到达 choking 状态所需的管道长度，称为剩余长度，表示为 $L^*$。
#
# #### 化简
# 三大控制方程中，只有动量守恒方程涉及长度，因此我们要从该方程出发，进行推导。方程两边除以 $\rho V^2$，摩擦项变量只剩 $\mathrm{d}L$，这样方便后续对距离积分。
# $$
# \mathrm{d}p+\rho V\mathrm{d}V+f_d\frac{dL}{D_h}\cdot\frac{\rho V^2}{2}=\frac{\mathrm{d}p}{\rho V^2}+\frac{\rho V\mathrm{d}V}{\rho V^2}+f_d\frac{dL}{2D_h}= \frac{\mathrm{d}p}{\rho V^2}+\frac{\mathrm{d}V}{V}+f_d\frac{dL}{2D_h}=0
# $$
# 代入速度关于马赫数表达式 $(V=Ma\sqrt{kRT})$ 到上式：
# $$
# \frac{\mathrm{d}p}{\underline{\underline{\rho}} Ma^2k\underline{\underline{RT}}}+\frac{\mathrm{d}V}{V}+f_d\frac{dL}{2D_h}=\frac{1}{kMa^2}\cdot\frac{\mathrm{d}p}{\underline{\underline{p}}}+\frac{\mathrm{d}V}{V}+f_d\frac{dL}{2D_h}=0
# $$
# #### 换元
# 现在要把 $\mathrm{d}p/p$ 和 $\mathrm{d}V/V$ 消掉，最好是能用马赫数表示。Fanno 流动中，各截面参数是距离的单值函数，并且还是单调变化的。这就意味着，所有参数都可以表示为其中某个参数的函数，比如马赫数的函数，即：$p=f(Ma),T=g(Ma),\rho=u(Ma),V=w(Ma)$。那么相应的变化率 $\mathrm{d}x/x$ 也可以统统表示为马赫数平方的变化率。这样看来，换元操作理论上是可行的。
#
# 温度关于滞止温度的表达式如下：
# $$
# T=\frac{T_0}{1+\frac{k-1}{2}Ma^2}
# $$
# 因为 Fanno 流动的滞止焓是守恒的，所以滞止温度也是守恒的。
#
# 对上式取对数：
# $$
# \ln{T}=\ln{\left(\frac{T_0}{1+\frac{k-1}{2}Ma^2}\right)}=\ln{T_0}-\ln\left({1+\frac{k-1}{2}Ma^2}\right)=-\ln\left({1+\frac{k-1}{2}Ma^2}\right)
# $$
# 对其微分：
# $$
# -\frac{\mathrm{d}(1+\frac{k-1}{2}Ma^2)}{1+\frac{k-1}{2}Ma^2}=\boxed{-\frac{k-1}{2}\frac{\mathrm{d}Ma^2}{1+\frac{k-1}{2}Ma^2}=\frac{\mathrm{d}T}{T}}
# $$
# 取速度关于马赫数表达式的对数：
# $$
# \ln V= \ln \left(Ma\sqrt{kRT}\right)= \ln Ma+ \frac{1}{2}\ln (kRT)=\ln Ma+ \frac{1}{2}\ln (kR)+\frac{1}{2}\ln T
# $$
# 对其微后再代入 $\mathrm{d}T/T$：
# $$
# \frac{\mathrm{d}Ma}{Ma}+0+\frac{1}{2}\frac{\mathrm{d}T}{T}=\frac{\mathrm{d}Ma}{Ma}-\frac{1}{2}\frac{k-1}{2}\frac{\mathrm{d}Ma^2}{1+\frac{k-1}{2}Ma^2}=\frac{\mathrm{d}Ma^2}{2Ma^2}-\frac{1}{2}\frac{k-1}{2}\frac{\mathrm{d}Ma^2}{1+\frac{k-1}{2}Ma^2}=\frac{4+2kMa^2-2Ma^2-2kMa^2+2Ma^2}{8Ma^2(1+\frac{k-1}{2}Ma^2)}\mathrm{d}Ma^2=\boxed{\frac{\mathrm{d}Ma^2}{2Ma^2(1+\frac{k-1}{2}Ma^2)}=\frac{\mathrm{d}V}{V}}
# $$
# 结合质量守恒方程和理想气体状态方程，将压力的变化率表示为：
# $$
# \left.
# \begin{aligned}
# \rho V = const \Longrightarrow \frac{\mathrm{d}\rho}{\rho}=-\frac{\mathrm{d}V}{V}\\[2ex]
# p=\rho RT \Longrightarrow \frac{\mathrm{d}p}{p}=\frac{\mathrm{d}\rho}{\rho}+\frac{\mathrm{d}T}{T}
# \end{aligned}
# \right\}
# \Longrightarrow \frac{\mathrm{d}p}{p}=\frac{\mathrm{d}T}{T}-\frac{\mathrm{d}V}{V}
# $$
# 代入已经推得的结果：
# $$
# -\frac{k-1}{2}\frac{\mathrm{d}Ma^2}{1+\frac{k-1}{2}Ma^2}-\frac{\mathrm{d}Ma^2}{2Ma^2(1+\frac{k-1}{2}Ma^2)}=\boxed{-\mathrm{d}Ma^2\frac{kMa^2-Ma^2+1}{2Ma^2(1+\frac{k-1}{2}Ma^2)}=\frac{\mathrm{d}p}{p}}
# $$
# #### 回代
# 将 $\mathrm{d}p/p$ 和 $\mathrm{d}V/V$ 的马赫数表达式代入开头化简后的动量守恒方程：
# $$
# \frac{1}{kMa^2}\cdot-\frac{kMa^2-Ma^2+1}{2Ma^2(1+\frac{k-1}{2}Ma^2)}\mathrm{d}Ma^2+\frac{\mathrm{d}Ma^2}{2Ma^2(1+\frac{k-1}{2}Ma^2)}=\frac{-kMa^2+Ma^2-1+kMa^2}{2kMa^4 \left( 1 + \frac{k-1}{2} Ma^2 \right)}\mathrm{d}Ma=\boxed{\frac{Ma^2-1}{2kMa^4 \left( 1 + \frac{k-1}{2} Ma^2 \right)}\mathrm{d}Ma^2=f_d\frac{dL}{2D_h}}
# $$
# #### 积分
# L 距离处马赫数是 Ma，$L_2$ 距离处马赫数是 $Ma_2$，分别作为上下，积分得到：
# $$
# \frac{f_d}{D_h}\int_{L}^{L_2}\mathrm{d}L=\int_{Ma}^{Ma_2}\frac{Ma^2-1}{k Ma^4[1+1/2(k -1)Ma^2]}\mathrm{d}Ma^2 \Longrightarrow \frac{f_d}{D_h} (L_2 - L)=\frac{1}{k}\left( \frac{1}{Ma^2} - \frac{1}{Ma_2^2} \right)+ \frac{k+1}{2k}\ln\left[\frac{Ma^2 \left( 1 + \frac{k-1}{2} Ma_2^2 \right)}{Ma_2^2 \left( 1 + \frac{k-1}{2} Ma^2 \right)}\right]
# $$
# 令 $Ma_2=1$，求得如下剩余管长 $(L_2 - L)$ 的计算式。
# $$
# \boldsymbol{
# \frac{f_d}{D_h}  L^{*}=\left(\frac{1-Ma^{2}}{k Ma^{2}}\right)+\frac{k + 1}{2k}\ln\left[\frac{(k + 1) Ma^{2}}{ 2 + (k-1) Ma^{2} }\right]
# }
# $$
#
# #### 验证
#
# 程序的输入如下：
#
# - **介质**：氮气
# - **初始压力**：20 bara
# - **初始温度**：20 °C
# - **初始流速**：100 m/s
# - **达西摩擦因子**：0.02
# - **管道内径**：0.1 m
# - **绝热指数**：1.4
# - **气体常数**：296.78 J/kg·K
#
# 初始马赫数计算为 0.28653，一起代入到上述表达式。
#
# $$
# L^* = \left\{ \frac{1-Ma^2}{k Ma^2} + \frac{k+1}{2k} \ln\left[{\frac{(k+1)Ma^2}{2+(k-1)Ma^2}}\right] \right \} \times \frac{D_h}{f_d}= \left\{ \frac{1-0.28653^2}{1.4 \times 0.28653^2} + \frac{1.4+1}{2 \times 1.4} \ln\left[{\frac{(1.4+1) \times 0.28653^2}{2+(1.42-1) \times 0.28653^2}}\right] \right\} \times \frac{0.1}{0.02} = 29.94\ \text{m}
# $$
# 可见，公式结果与程序结果几乎一致。
# ### 压降计算
# 对上节推导出来的 $\mathrm{d}x/x$ 分别积分，可得到任意两个点的参数比与对应马赫数的关系式。
# \begin{align*}
# \int_{p_1}^{p_2}\frac{dp}{p}&=\int_{Ma_1}^{Ma_2}-\frac{kMa^2-Ma^2+1}{2Ma^2(1+\frac{k-1}{2}Ma^2)}\, d(Ma^2)&\Longrightarrow&
# \boxed{\frac{p_2}{p_1}=\frac{Ma_1}{Ma_2}\left(\frac{1+\frac{k-1}{2}Ma_1^2}{1+\frac{k-1}{2}Ma_2^2}\right)^{1/2}}\\[2ex]
# \int_{T_1}^{T_2}\frac{dT}{T}&=\int_{Ma_1}^{Ma_2}-\frac{k-1}{2(1+\frac{k-1}{2}Ma^2)}\, d(Ma^2)
# &\Longrightarrow&\boxed{\frac{T_2}{T_1}=\frac{1+\frac{k-1}{2}Ma_1^2}{1+\frac{k-1}{2}Ma_2^2}}\\[2ex]
# \int_{V_1}^{V_2}\frac{dV}{V}&=\int_{Ma_1}^{Ma_2}\frac{1}{2Ma^2(1+\frac{k-1}{2}Ma^2)}\, d(Ma^2)&\Longrightarrow&
# \boxed{\frac{V_2}{V_1}=\frac{Ma_2}{Ma_1}\left(\frac{1+\frac{k-1}{2}Ma_1^2}{1+\frac{k-1}{2}Ma_2^2}\right)^{1/2}=\frac{\rho_1}{\rho_2}}
# \end{align*}
# 再结合“剩余长度”公式，提出 Fanno 流压降的计管方法。
# 1. 根据起点马赫数计算起点剩余长度
# 2. 根据两点距离得到终点剩余长度
# 3. 根据终点剩余长度反向计算终点马赫数
# 4. 根据两点马赫数，计算压比，得到终点处压力。
#
# 示例代码如下，计算结果与分段计算一致。

# %%
import math

# ========================================================================================
# Fanno Flow -Given point1 state and distance dx, solve point2 pressure.
#
# Assumptions:
# - Ideal gas, adiabatic, constant area pipe (Fanno flow)
# - Darcy friction factor fd is used (NOT Fanning)
# - Subsonic inlet only (Ma1 < 1). For Ma1>1, the direction/logic differs.
# ========================================================================================

# Gas properties (Nitrogen example)
R = 296.78  # J/kg·K
K = 1.4  # ratio of specific heats

# Numerical settings for Mach inversion
TOL = 1e-12
MAX_ITER = 200


def Lstar2Ma(Lstar, fd, D):
    """
    Invert Mach number from given Lstar.
    Uses fixed-point iteration.
    """
    # Initial guess
    Ma = 0.5
    counter = 0
    target = Lstar * fd / D
    while counter < MAX_ITER:
        term1 = (1.0 - Ma * Ma) / (K * Ma * Ma)
        term2 = (K + 1.0) / (2.0 * K) * math.log(((K + 1.0) * Ma * Ma) / (2.0 + (K - 1.0) * Ma * Ma))
        Lstar_calc = term1 + term2

        # Update Mach using relaxation
        Ma_new = Ma * (Lstar_calc / target) ** 0.8  # simple relaxation can facilitate convergence

        # Convergence check
        if abs(Ma_new - Ma) < TOL:
            return Ma_new

        Ma = Ma_new
        counter += 1

    raise RuntimeError("Lack of convergence in Lstart2Ma")


def clac_pressure_ratio(Ma1, fd, D, dx):

    # 1) point1 remaining length
    term1 = (1.0 - Ma1 * Ma1) / (K * Ma1 * Ma1)
    term2 = (K + 1.0) / (2.0 * K) * math.log(((K + 1.0) * Ma1 * Ma1) / (2.0 + (K - 1.0) * Ma1 * Ma1))
    Lstar1 = (term1 + term2) * (D / fd)

    # 2) point2 remaining length
    Lstar2 = Lstar1 - dx

    # 3) invert Mach2 (or choke)
    if Lstar2 <= 0.0:
        Ma2 = 1.0
    else:
        Ma2 = Lstar2Ma(Lstar2, fd, D)

    # 4) compute pressure ratio
    a1 = 1.0 + (K - 1.0) / 2.0 * Ma1 * Ma1
    a2 = 1.0 + (K - 1.0) / 2.0 * Ma2 * Ma2
    pr = (Ma1 / Ma2) * math.sqrt(a1 / a2)
    # Tr = a1 / a2
    # Vr = (Ma2 / Ma1) * math.sqrt(a1 / a2)

    return pr


if __name__ == "__main__":
    # distance between point 1 and 2
    dx = 19.0  # m

    p1 = 20e5
    T1 = 20.0 + 273.15
    V1 = 100.0
    fd = 0.02
    D = 0.1
    Ma1 = V1 / math.sqrt(K * R * T1)

    pr = clac_pressure_ratio(Ma1, fd, D, dx)
    p2 = p1 * pr
    print(f"p2 = {p2/1E5:.3f} bara @ dL = {dx} m")
# Out:
# p2 = 13.967 bara @ dL = 19.0 m

# %% [markdown]
# ## 等温管流
# 因为只需求压力和速度这两个未知量，所以等温流动的计算要相对简单些，并只用到质量守恒方程和动量守恒方程。
# ### 方程化简
# 同绝热流动化简后的动量方程：
# $$
# p_1 + \frac{p_1}{RT_1} V_1^2=\color{magenta}{p_2}+ V_1^2 \cdot \frac{p_1^2 \color{magenta}{T_2}}{RT_1^2\color{magenta}{p_2} }+ f_d \frac{\mathrm{d}L}{D_h} \cdot \frac{p_1 V_1^2}{2RT_1}
# $$
# ### 编程实现
# 编程思路与绝热流动相同，退化为求解单个动量方程，数值方法还用不动点迭代。

# %%
from tabulate import tabulate

# ========================================================================================
# Isothermal Flow - Multi-Segment Solver (SI Units)
# Author: Robin Han
# Date: December, 2025
# All variables are in SI:
# Pressure (Pa), Temperature (K), Velocity (m/s), Length (m), Diameter (m), R (J/kg·K)
# ========================================================================================

# Nitrogen properties
R = 8.314 / 28.014e-3  # J/kg·K (specific gas constant for N2)
CP = 1072.0  # J/kg·K (specififc heat at constant pressure@20bara/20C)
K = 1.4  # ratio of specific heats for diatomic gas (approx)

# Numerical parameters
TOL = 1e-6  # convergence tolerance for p2 and T2
MAX_ITER = 200  # maximum iterations per segment


def isothermal_segment(p1, T, V1, fd, D, dL):
    """
    Solve one Isothermal-flow segment using fixed-point iteration.

    Inputs:
        p1 : inlet pressure  (Pa)
        T : inlet temperature (K)
        V1 : inlet velocity (m/s)

    Returns:
        p2 : outlet pressure (Pa)
        V2 : outlet velocity (m/s)
    """

    # Initial guesses for unknown outlet values
    p2 = 0.95 * p1

    counter = 0
    while counter < MAX_ITER:
        # --- Update pressure from momentum equation ---
        # p1 + (p1/(RG*T))*V1^2 = p2 + V1^2 * (p1^2 * T2)/(RG*T^2 * p2) + F*L/D *K*(p1*V1^2)/(2*RG*T)
        # -> p2 = p1 + (p1*V1^2)/(RG*T) - V1^2 * p1^2 * T / (RG*T^2*p2) - F*L/D * p1 * V1^2 / (2*RG*T)
        p2_new = p1 + (p1 * V1**2) / (R * T) - (V1**2 * p1**2 * T) / (R * T**2 * p2) - (fd * dL / D * p1 * V1**2) / (2 * R * T)

        # Convergence check on both pressure and temperature
        if (abs(p2_new - p2)) < TOL:
            p2 = p2_new
            break

        # Go to next iteration using updated values
        p2 = p2_new
        counter += 1
    else:
        # Only executed if while loop exits without break
        raise RuntimeError("Lack of convergence in fanno_segment")

    # --- Compute outlet velocity using mass conservation ---
    # rho1 * V1 = rho2 * V2, rho = P / (RG*T)
    rho1 = p1 / (R * T)
    rho2 = p2 / (R * T)
    V2 = rho1 * V1 / rho2

    return p2, V2


def isothermal_pipe(p0, T, V0, fd, D, dL):
    """
    March along the pipe using multiple Fanno segments.
    Uses an infinite loop to advance segment by segment
    until:
      - lack of convergence (numerical issue), or
      - choking (Mach number close to 1)

    Returns:
        results : list of (P, T, V, M) at each segment outlet
    """

    total_length = 0.0
    results = []

    p1, V1 = p0, V0
    while True:
        try:
            p2, V2 = isothermal_segment(p1, T, V1, fd, D, dL)
        except RuntimeError as e:
            print(f"\n[Warning] {e}. Stopping at length = {total_length:.3f} m")
            break

        total_length += dL
        c2 = (K * R * T) ** 0.5
        Ma2 = V2 / c2
        results.append((total_length, p2, T, V2, Ma2))

        p1, V1 = p2, V2
    return results


if __name__ == "__main__":
    # 20 bara, 20 C, 100 m/s, fd = 0.02, D = 0.1, dL = 0.1
    profile = isothermal_pipe(20e5, 20.0 + 273.15, 100.0, 0.02, 0.1, 0.1)

    headers = ["No.", "Length (m)", "Pressure (bara)", "Temp (C)", "Velocity (m/s)", "Mach Number"]
    table_data = []
    for i, (L, p, t, v, ma) in enumerate(profile):
        table_data.append([i, f"{L:.3f}", f"{p/1E5:.3f}", f"{t-273.15:.1f}", f"{v:.3f}", f"{ma:.3f}"])

    print(tabulate(table_data, headers=headers, tablefmt="grid", stralign="center", numalign="center"))
# Out:
# [Warning] Lack of convergence in fanno_segment. Stopping at length = 27.700 m
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  No.  |  Length (m)  |  Pressure (bara)  |  Temp (C)  |  Velocity (m/s)  |  Mach Number  |
# +=======+==============+===================+============+==================+===============+
# |   0   |     0.1      |      19.974       |     20     |      100.13      |     0.287     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |   1   |     0.2      |      19.948       |     20     |     100.261      |     0.287     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |   2   |     0.3      |      19.922       |     20     |     100.392      |     0.288     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |   3   |     0.4      |      19.896       |     20     |     100.524      |     0.288     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |   4   |     0.5      |       19.87       |     20     |     100.656      |     0.288     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |   5   |     0.6      |      19.843       |     20     |     100.789      |     0.289     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |   6   |     0.7      |      19.817       |     20     |     100.922      |     0.289     |
# +-------+--------------+-------------------+------------+------------------+---------------+
#
|
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  244  |     24.5     |      10.928       |     20     |     183.022      |     0.524     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  245  |     24.6     |      10.859       |     20     |      184.18      |     0.528     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  246  |     24.7     |      10.789       |     20     |      185.37      |     0.531     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  247  |     24.8     |      10.719       |     20     |     186.593      |     0.535     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  248  |     24.9     |      10.647       |     20     |     187.852      |     0.538     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  249  |      25      |      10.574       |     20     |     189.149      |     0.542     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  250  |     25.1     |      10.499       |     20     |     190.486      |     0.546     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  251  |     25.2     |      10.424       |     20     |     191.866      |     0.55      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  252  |     25.3     |      10.347       |     20     |     193.291      |     0.554     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  253  |     25.4     |      10.269       |     20     |     194.765      |     0.558     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  254  |     25.5     |      10.189       |     20     |     196.292      |     0.562     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  255  |     25.6     |      10.107       |     20     |     197.875      |     0.567     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  256  |     25.7     |      10.024       |     20     |     199.519      |     0.572     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  257  |     25.8     |       9.939       |     20     |     201.229      |     0.577     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  258  |     25.9     |       9.852       |     20     |      203.01      |     0.582     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  259  |      26      |       9.762       |     20     |      204.87      |     0.587     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  260  |     26.1     |       9.67        |     20     |     206.815      |     0.593     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  261  |     26.2     |       9.576       |     20     |     208.854      |     0.598     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  262  |     26.3     |       9.479       |     20     |     210.997      |     0.605     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  263  |     26.4     |       9.378       |     20     |     213.258      |     0.611     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  264  |     26.5     |       9.274       |     20     |     215.649      |     0.618     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  265  |     26.6     |       9.166       |     20     |     218.189      |     0.625     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  266  |     26.7     |       9.054       |     20     |     220.899      |     0.633     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  267  |     26.8     |       8.936       |     20     |     223.807      |     0.641     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  268  |     26.9     |       8.813       |     20     |     226.946      |     0.65      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  269  |      27      |       8.682       |     20     |     230.363      |     0.66      |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  270  |     27.1     |       8.543       |     20     |      234.12      |     0.671     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  271  |     27.2     |       8.393       |     20     |     238.306      |     0.683     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  272  |     27.3     |       8.229       |     20     |     243.052      |     0.696     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  273  |     27.4     |       8.046       |     20     |     248.576      |     0.712     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  274  |     27.5     |       7.835       |     20     |     255.275      |     0.731     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  275  |     27.6     |       7.574       |     20     |     264.057      |     0.757     |
# +-------+--------------+-------------------+------------+------------------+---------------+
# |  276  |     27.7     |       7.182       |     20     |     278.474      |     0.798     |
# +-------+--------------+-------------------+------------+------------------+---------------+

# %% [markdown]
# ### 流动方程
# 等温流动的流速上限低于声速，本节首先推导出这一上限的计算公式，再推导对应的剩余管长公式，最后推导工程上常用的管道出口压力简化公式。
# #### 马赫数上限
# 由声速和马赫数的定义及理想气体状态方程推导得到：
# $$
# \begin{align*}
# &\left.
# \begin{aligned}
# &Ma\equiv \frac{v}{c}\\[2ex]
# &c=\sqrt{k RT}\\[2ex]
# &p=\rho RT
# \end{aligned}
# \right\}\Longrightarrow v^2=Ma^2c^2=Ma^2k R T \Longrightarrow \rho v^2=\rho Ma^2k R T=    \rho Ma^2k \frac{p}{\rho}=pk Ma^2
# \end{align*}
# $$
#
# 动量方程两边除以压力后将上式代入:
# $$
# \frac{\mathrm{d}p}{p}+\frac{\rho V\mathrm{d}V}{p}+f_d\frac{\mathrm{d}L}{D_h}\frac{\rho V^2}{2p}=0\\[2ex]
# \frac{\rho V\mathrm{d}V}{p}=\frac{\rho V^2\mathrm{d}V}{pV}=\frac{k p Ma^2\mathrm{d}V}{pV}=k Ma^2\frac{\mathrm{d}V}{V}\\[2ex]
# f_d\frac{\mathrm{d}L}{D_h}\frac{\rho V^2}{2p}=f_d\frac{\mathrm{d}L}{D_h}\frac{k pMa^2}{2p}=f_d\frac{\mathrm{d}L}{D_h}\frac{k Ma^2}{2}\\[2ex]
# \Downarrow\\
# \frac{\mathrm{d}p}{p}+k Ma^2\frac{\mathrm{d}V}{V}+k Ma^2\frac{\mathrm{d}L}{2D_h}f_d=0
# $$
#
# 现在设法将 $\mathrm{d}V/V$ 用 $\mathrm{d}p/p$ 表示。利用质量守恒方程和等温流动的理想气体状态方程即可实现。
# $$
# \begin{align*}
# &\left.
# \begin{aligned}
# &\rho V = const \Longrightarrow \frac{\mathrm{\rho}}{\rho}+\frac{\mathrm{d}V}{V}=0\\[2ex]
# &p\frac{1}{\rho}=const \Longrightarrow \frac{\mathrm{d}p}{p}= \frac{\mathrm{\rho}}{\rho}\\
# \end{aligned}
# \right\}\Longrightarrow \frac{\mathrm{d}V}{V}=-\frac{\mathrm{d}p}{p}
# \end{align*}
# $$
#
# 压降的微分表达式推导如下：
# $$
# \frac{\mathrm{d}p}{p}-k Ma^2\frac{\mathrm{d}p}{p}+k Ma^2\frac{\mathrm{d}L}{2D_h}f_d=0 \Longrightarrow \boxed{\frac{\mathrm{d}p}{p}+\left( \frac{k Ma^2}{1-k Ma^2}\right)\frac{f_d}{2D_h}\mathrm{d}L=0}
# $$
#
# 从公式可知，等温流动的马赫数上限是 ${\dfrac{1}{\sqrt{k}}}$。
# #### 剩余管长公式
# 等温流动声速不变，可得如下关系式：
# $$
# \frac{\mathrm{d}V}{V}=\frac{\mathrm{d}Ma}{Ma}=-\frac{\mathrm{d}p}{p}
# $$
# 代入到上节微分表达式，得到：
# $$
# \left( \frac{k Ma^2}{1-k Ma^2}\right)\frac{f_d}{2D_h}\mathrm{d}L=\frac{\mathrm{d}Ma}{Ma} \Longrightarrow \frac{1-kMa^2}{Ma^3}\mathrm{d}Ma=\frac{f_d}{2D_h}\mathrm{d}L
# $$
#
# 令马赫数上限为${\dfrac{1}{\sqrt{k}}}$，积分得到：
# $$
# \frac{f}{2D_h} \int_0^{L^*} dL = \int_{Ma}^{1/\sqrt{k}} \frac{1-kMa^2}{kMa^3}dMa \Longrightarrow \boxed{\frac{f_d L^*}{D_h} = \frac{1-k Ma^2}{k Ma^2} + \ln(k Ma^2)}
# $$
#
# #### 出口压力简化计算
# 根据连续性方程、理想气体状态方程和等温流动假设：
# $$
# \frac{p_1}{p}=\frac{\rho_1}{\rho}=\frac{V}{V_1}\Longrightarrow \frac{\rho_1^2}{\rho^2}=\frac{V^2}{V_1^2} \Longrightarrow \frac{\rho_1V_1^2}{\rho V^2}=\frac{\rho}{\rho_1}=\frac{p}{p_1}\Longrightarrow\frac{1}{\rho V^2}=\frac{p}{\rho_1V_1^2p_1}
# $$
#
# 动量守恒方程两边除以 $\rho V^2/2$ 将上式代入：
# $$
# \frac{2\mathrm{d}p}{\rho V^2}+2\frac{\mathrm{d}V}{V}+\frac{f_d}{D_h}\mathrm{d}L=0\Longrightarrow \frac{2p\mathrm{d}p}{\rho_1V_1^2p_1}+2\frac{\mathrm{d}V}{V}+\frac{f_d}{D_h}\mathrm{d}L=0
# $$
#
# 截面1到截面2的距离为 L，积分为：
# $$
# \frac{2}{\rho_1V_1^2p_1}\int_{1}^{2} p\,\mathrm{d}p+2\int_{1}^{2} \frac{1}{V}\,\mathrm{d}V+\frac{f_d}{D_h}\int_{1}^{2} \,\mathrm{d}L=0 \Longrightarrow p_1^2-p_2^2=\rho_1V_1^2p_1\left(2\ln{\frac{V_2}{V_1}+\frac{f_dL}{D_h}}\right)
# $$
#
# 长管道一般满足如下条件：
# $$
# 2\ln{\frac{V_2}{V_1}} \ll \frac{f_dL}{D_h}
# $$
#
# 则上式可简化为：
# $$
# p_1^2-p_2^2=\rho_1V_1^2p_1\frac{f_dL}{D_h}\Longrightarrow p_2=p_1\sqrt{1-\frac{\rho_1V_1^2}{p_1}\cdot\frac{f_dL}{D_h}}
# $$
#
# 因为是等温流动，所以 $RT$ 是常数，则：
# $$
# \frac{\rho_1}{p_1}=\frac{1}{RT}
# $$
#
# 这样就得到了等温流动计算 $p_2$ 的最终表达式：
# $$
# \boxed{p_2=p_1\sqrt{1-\frac{V_1^2}{RT}\cdot\frac{f_dL}{D_h}}}
# $$
#
# #### 方程验证
#
# 程序的主要输入如下：
#
# - **介质**：氮气
# - **初始压力**：20 bara
# - **初始温度**：20 °C
# - **初始流速**：100 m/s
# - **达西摩擦因子**：0.02
# - **管道内径**：0.1 m
# - **绝热指数**：1.4
# - **气体常数**：296.78 J/kg·K
#
# 初始马赫数计算为 0.28653，一起代入到剩余管长计算公式。
#
# $$
# L^* = \left[ \frac{1-k Ma^2}{k Ma^2} + \ln(k Ma^2) \right ] \cdot \frac{D_h}{f_d}=\left[ \frac{1-1.4\times 0.28653^2}{1.4\times 0.28653^2} + \ln(1.4\times0.28653^2) \right ]\times\frac{0.1}{0.02}=27.69 \;\text{m}
# $$
#
# 可见，公式结果与程序结果一致。
#
# ## 收缩喷嘴

# %% [markdown]
# ## 符号说明
# ### 主要符号
# $$
# \begin{align*}
# p    &\quad \text{压力（bara）} \\
# T    &\quad \text{热力学温度（K）} \\
# V    &\quad \text{流速（m/s）} \\
# h    &\quad \text{比焓（J/kg）} \\
# R    &\quad \text{气体常数 } \mathrm{J/(kg\cdot K)} \\
# k    &\quad \text{绝热指数} \\
# L    &\quad \text{长度（m）} \\
# D_h  &\quad \text{水力直径（m）} \\
# f_d  &\quad \text{达西摩擦系数}
# \end{align*}
# $$
#
# ### 上下标
#
# $$
# \begin{align*}
# 1    &\quad \text{进口} \\
# 2    &\quad \text{出口} \\
# \end{align*}
# $$
